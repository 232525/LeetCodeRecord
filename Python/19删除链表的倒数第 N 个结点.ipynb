# %%
import typing
from typing import List

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
class Solution1:
    def removeNthFromEnd(self, head: ListNode, n: int) -> ListNode:
        left = head
        right = head.next
        # 链表长度为1，直接返回空指针
        if left.next is None:
            del head
            return None
        # 获取链表长度，至少为2
        len_head = 2
        while(right.next is not None):
            len_head += 1
            left = left.next
            right = right.next
            
        # 如果要删除最后一个元素，此时可以直接删除返回
        if n == 1:
            left.next = right.next
            del right
            return head

        # 否则，再次循环，找到要删除的节点进行删除
        delete_idx = len_head - n
        # 如果要删除第一个节点，也可以直接删除返回
        if delete_idx == 0:
            head = head.next
            return head
        
        # 删除中间节点，则需要找到要删除的位置
        left = head
        right = head.next
        for i in range(delete_idx+1):
            if i+1 == delete_idx:
                print(left.val, right.val)
                left.next = right.next
                del right
                break
            else:
                left = right
                right = right.next
        return head

class Solution:
    def removeNthFromEnd(self, head: ListNode, n: int) -> ListNode:
        """
        # 双指针-方法1
        left_idx = -n

        # 在头部添加一个节点
        new_head = ListNode(0, head)
        left = None
        right = new_head
        while(right is not None):
            right = right.next
            if left is not None:
                left = left.next
            if left_idx == 0:
                left = new_head
            left_idx += 1
        left.next = left.next.next
        """
        
        # 双指针-方法2：直接先移动右指针到正确位置，然后一起移动左右指针（左右指针之间相隔n个节点）
        new_head = ListNode(0, head)
        left = new_head  # 左指针初始位置置于new_head处
        right = head
        # 先移动右指针
        for i in range(n):
            right = right.next
        
        # 然后一起移动左右指针
        while(right is not None):
            right = right.next
            left = left.next
            
        left.next = left.next.next
        
        return new_head.next

# %%
head = ListNode(1, ListNode(2, ListNode(3, ListNode(4, ListNode(5)))))
# head = ListNode(1, ListNode(2))
head = ListNode(1)
_ = Solution().removeNthFromEnd(head, 1)
_ptr = _
while(_ptr is not None):
    print(_ptr.val, end=" ")
    _ptr = _ptr.next
